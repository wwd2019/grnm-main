# %%
1️⃣ 数据准备与预处理

目标：读取原始 RNA/ATAC 数据，构建 Seurat/URD 对象，统一注释。
相关文件：

changetfname.R

功能：修改或统一基因名（例如 SYMBOL → gene_id），保证后续分析一致性。

changeannotationname.R

功能：修改 peak/基因注释名称（例如 ATAC peaks 的染色体位点格式），统一格式。

getPersonMatrix.R

功能：计算 TF-TF Pearson 相关矩阵，为后续 GRN 网络构建准备
